# %%
df=pd.read_csv('/kaggle/input/job-placement-dataset/Job_Placement_Data.csv')
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
df.shape
# Out:
# (215, 13)

# %%
df.isnull()
# Out:
#      gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  \
# 0     False           False      False           False      False
# 1     False           False      False           False      False
# 2     False           False      False           False      False
# 3     False           False      False           False      False
# 4     False           False      False           False      False
# ..      ...             ...        ...             ...        ...
# 210   False           False      False           False      False
# 211   False           False      False           False      False
# 212   False           False      False           False      False
# 213   False           False      False           False      False
# 214   False           False      False           False      False
#
#      hsc_subject  degree_percentage  undergrad_degree  work_experience  \
# 0          False              False             False            False
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# ssc_percentage         0
# ssc_board              0
# hsc_percentage         0
# hsc_board              0
# hsc_subject            0
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         0
# mba_percent            0
# status                 0
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['gender'] = df['gender'].replace(['M','F'],[0,1])
df
# Out:
# /tmp/ipykernel_33/2424148781.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'] = df['gender'].replace(['M','F'],[0,1])
#      gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0         0           67.00    Others           91.00    Others    Commerce
# 1         0           79.33   Central           78.33    Others     Science
# 2         0           65.00   Central           68.00   Central        Arts
# 3         0           56.00   Central           52.00   Central     Science
# 4         0           85.80   Central           73.60   Central    Commerce
# ..      ...             ...       ...             ...       ...         ...
# 210       0           80.60    Others           82.00    Others    Commerce
# ...

# %%
df['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
df['specialisation'] = df['specialisation'].replace(['Mkt&HR','Mkt&Fin'],[0,1])
df
# Out:
# /tmp/ipykernel_33/238048750.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['specialisation'] = df['specialisation'].replace(['Mkt&HR','Mkt&Fin'],[0,1])
#      gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0         0           67.00    Others           91.00    Others    Commerce
# 1         0           79.33   Central           78.33    Others     Science
# 2         0           65.00   Central           68.00   Central        Arts
# 3         0           56.00   Central           52.00   Central     Science
# 4         0           85.80   Central           73.60   Central    Commerce
# ..      ...             ...       ...             ...       ...         ...
# ...

# %%
df['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
df['status'] = df['status'].replace(['Not Placed','Placed'],[0,1])
df
# Out:
# /tmp/ipykernel_33/2640962256.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['status'] = df['status'].replace(['Not Placed','Placed'],[0,1])
#      gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0         0           67.00    Others           91.00    Others    Commerce
# 1         0           79.33   Central           78.33    Others     Science
# 2         0           65.00   Central           68.00   Central        Arts
# 3         0           56.00   Central           52.00   Central     Science
# 4         0           85.80   Central           73.60   Central    Commerce
# ..      ...             ...       ...             ...       ...         ...
# ...

# %%
df['work_experience'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['work_experience'] = df['work_experience'].replace(['No','Yes'],[0,1])
df
# Out:
# /tmp/ipykernel_33/3170183166.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['work_experience'] = df['work_experience'].replace(['No','Yes'],[0,1])
#      gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0         0           67.00    Others           91.00    Others    Commerce
# 1         0           79.33   Central           78.33    Others     Science
# 2         0           65.00   Central           68.00   Central        Arts
# 3         0           56.00   Central           52.00   Central     Science
# 4         0           85.80   Central           73.60   Central    Commerce
# ..      ...             ...       ...             ...       ...         ...
# ...

# %%
col_to_drop = ['ssc_board','hsc_board']
col_to_drop
# Out:
# ['ssc_board', 'hsc_board']

# %%
df.drop(columns = col_to_drop,inplace =True)
df
# Out:
#      gender  ssc_percentage  hsc_percentage hsc_subject  degree_percentage  \
# 0         0           67.00           91.00    Commerce              58.00
# 1         0           79.33           78.33     Science              77.48
# 2         0           65.00           68.00        Arts              64.00
# 3         0           56.00           52.00     Science              52.00
# 4         0           85.80           73.60    Commerce              73.30
# ..      ...             ...             ...         ...                ...
# 210       0           80.60           82.00    Commerce              77.60
# 211       0           58.00           60.00     Science              72.00
# 212       0           67.00           67.00    Commerce              73.00
# 213       1           74.00           66.00    Commerce              58.00
# 214       0           62.00           58.00     Science              53.00
#
# ...

# %%
df.drop(columns =['hsc_subject'],inplace =True)
df
# Out:
#      gender  ssc_percentage  hsc_percentage  degree_percentage  \
# 0         0           67.00           91.00              58.00
# 1         0           79.33           78.33              77.48
# 2         0           65.00           68.00              64.00
# 3         0           56.00           52.00              52.00
# 4         0           85.80           73.60              73.30
# ..      ...             ...             ...                ...
# 210       0           80.60           82.00              77.60
# 211       0           58.00           60.00              72.00
# 212       0           67.00           67.00              73.00
# 213       1           74.00           66.00              58.00
# 214       0           62.00           58.00              53.00
#
#     undergrad_degree  work_experience  emp_test_percentage  specialisation  \
# 0           Sci&Tech                0                 55.0               0
# ...

# %%
df['undergrad_degree'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
df['undergrad_degree'] = df['undergrad_degree'].replace(['Sci&Tech', 'Comm&Mgmt', 'Others'],[0,1,2])
df
# Out:
# /tmp/ipykernel_33/2700489412.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['undergrad_degree'] = df['undergrad_degree'].replace(['Sci&Tech', 'Comm&Mgmt', 'Others'],[0,1,2])
#      gender  ssc_percentage  hsc_percentage  degree_percentage  \
# 0         0           67.00           91.00              58.00
# 1         0           79.33           78.33              77.48
# 2         0           65.00           68.00              64.00
# 3         0           56.00           52.00              52.00
# 4         0           85.80           73.60              73.30
# ..      ...             ...             ...                ...
# 210       0           80.60           82.00              77.60
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data_input =df.drop(columns=['status'])
data_output =df['status']

# %%
data_input.shape
# Out:
# (215, 9)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_input,data_output, test_size=0.2)

# %%
X_train.shape
# Out:
# (172, 9)

# %%
model =LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8604651162790697
